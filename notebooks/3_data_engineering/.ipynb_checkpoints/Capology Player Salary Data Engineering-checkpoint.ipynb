# %% [markdown]
# <a id='top'></a>

# %% [markdown]
# # Capology Player Web Scraping
# ##### Notebook to engineer scraped data
#
# ### By [Edd Webster](https://www.twitter.com/eddwebster)
# Notebook first written: 01/08/2021<br>
# Notebook last updated: 07/08/2021
#
# ![title](../../img/logos/capology-logo.jpeg)
#
# Click [here](#section5) to jump straight to the Exploratory Data Analysis section and skip the [Task Brief](#section2), [Data Scraping](#section3), and [Data Unification](#section4) sections. Or click [here](#section5) to jump straight to the Conclusion.

# %% [markdown]
# ___
#
# <a id='sectionintro'></a>
#
# ## <a id='import_libraries'>Introduction</a>
# This notebook scrapes player statstics data from [Capology](https://www.capology.com/), using [pandas](http://pandas.pydata.org/) for data manipulation through DataFrames, and [Selenium](https://www.selenium.dev/) and [Beautifulsoup](https://pypi.org/project/beautifulsoup4/) for webscraping.
#
# For more information about this notebook and the author, I'm available through all the following channels:
# *    [eddwebster.com](https://www.eddwebster.com/);
# *    edd.j.webster@gmail.com;
# *    [@eddwebster](https://www.twitter.com/eddwebster);
# *    [linkedin.com/in/eddwebster](https://www.linkedin.com/in/eddwebster/);
# *    [github/eddwebster](https://github.com/eddwebster/);
# *    [public.tableau.com/profile/edd.webster](https://public.tableau.com/profile/edd.webster);
# *    [kaggle.com/eddwebster](https://www.kaggle.com/eddwebster); and
# *    [hackerrank.com/eddwebster](https://www.hackerrank.com/eddwebster).
#
# ![title](../../img/fifa21eddwebsterbanner.png)
#
# The accompanying GitHub repository for this notebook can be found [here](https://github.com/eddwebster/football_analytics) and a static version of this notebook can be found [here](https://nbviewer.jupyter.org/github/eddwebster/football_analytics/blob/master/notebooks/3_data_engineering/Capology%20Player%20Salary%20Data%20Engineering.ipynb).

# %% [markdown]
# ___
#
# <a id='sectioncontents'></a>
#
# ## <a id='notebook_contents'>Notebook Contents</a>
# 1.    [Notebook Dependencies](#section1)<br>
# 2.    [Project Brief](#section2)<br>
# 3.    [Data Sources](#section3)<br>
# 4.    [Data Engineering](#section4)<br>
# 5.    [Export Data](#section5)<br>
# 6.    [Summary](#section6)<br>
# 7.    [Next Steps](#section7)<br>
# 8.    [Bibliography](#section8)<br>

# %% [markdown]
# ___
#
# <a id='section1'></a>
#
# ## <a id='#section1'>1. Notebook Dependencies</a>
#
# This notebook was written using [Python 3](https://docs.python.org/3.7/) and requires the following libraries:
# *    [`Jupyter notebooks`](https://jupyter.org/) for this notebook environment with which this project is presented;
# *    [`NumPy`](http://www.numpy.org/) for multidimensional array computing; and
# *    [`pandas`](http://pandas.pydata.org/) for data analysis and manipulation.
#
# All packages used for this notebook except for [`Beautifulsoup`](https://pypi.org/project/beautifulsoup4/) and [`Selenium`](https://www.selenium.dev/) can be obtained by downloading and installing the [Conda](https://anaconda.org/anaconda/conda) distribution, available on all platforms (Windows, Linux and Mac OSX). Step-by-step guides on how to install Anaconda can be found for Windows [here](https://medium.com/@GalarnykMichael/install-python-on-windows-anaconda-c63c7c3d1444) and Mac [here](https://medium.com/@GalarnykMichael/install-python-on-mac-anaconda-ccd9f2014072), as well as in the Anaconda documentation itself [here](https://docs.anaconda.com/anaconda/install/).

# %% [markdown]
# ### Import Libraries and Modules

# %%
# Python ≥3.5 (ideally)
import platform
import sys, getopt
assert sys.version_info >= (3, 5)
import csv

# Import Dependencies
# %matplotlib inline

# Math Operations
import numpy as np
from math import pi

# Datetime
import datetime
from datetime import date
import time

# Data Preprocessing
import pandas as pd
#import pandas_profiling as pp
import os
import re
import random
import glob
from io import BytesIO
from pathlib import Path

# Reading directories
import glob
import os

# Working with JSON
import json
from pandas.io.json import json_normalize

# Web Scraping
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
from bs4 import BeautifulSoup
import re

# Currency Converter
from currency_converter import CurrencyConverter

# Data Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-whitegrid')
import missingno as msno

# Progress Bar
from tqdm import tqdm

# Display in Jupyter
from IPython.display import Image, Video, YouTubeVideo
from IPython.core.display import HTML

# Ignore Warnings
import warnings
warnings.filterwarnings(action='ignore', message='^internal gelsd')

print('Setup Complete')
# Out:
# Setup Complete
# <ipython-input-3-1bc95b05712d>:51: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
# Python / module versions used here for reference
print('Python: {}'.format(platform.python_version()))
print('NumPy: {}'.format(np.__version__))
print('pandas: {}'.format(pd.__version__))
# Out:
# Python: 3.8.8
# NumPy: 1.20.1
# pandas: 1.4.4

# %% [markdown]
# ### Defined Variables and Lists

# %% [markdown]
# ##### Date

# %%
# Define today's date
today = datetime.datetime.now().strftime('%d/%m/%Y').replace('/', '')

# %%
# Define variables and lists

## Define season
season = '2022'    # '2020' for the 20/21 season

# Create 'Full Season' and 'Short Season' strings

## Full season
full_season_string = str(int(season)) + '/' + str(int(season) + 1)

## Short season
short_season_string = str((str(int(season))[-2:]) + (str(int(season) + 1)[-2:]))

# %% [markdown]
# ### Defined Filepaths

# %%
# Set up initial paths to subfolders
base_dir = os.path.join('..', '..')
data_dir = os.path.join(base_dir, 'data')
data_dir_capology = os.path.join(base_dir, 'data', 'capology')
img_dir = os.path.join(base_dir, 'img')
fig_dir = os.path.join(base_dir, 'img', 'fig')

# %% [markdown]
# ### Create Directory Structure

# %%
# Make the directory structure
for folder in ['archive']:
    path = os.path.join(data_dir_capology, 'engineered', folder)
    if not os.path.exists(path):
        os.mkdir(path)

# %% [markdown]
# ### Notebook Settings

# %%
# Display all columns of displayed pandas DataFrames
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None

# %% [markdown]
# ---
#
# <a id='section2'></a>
#
# ## <a id='#section2'>2. Project Brief</a>

# %% [markdown]
# ### <a id='#section2.1'>2.1. About this notebook</a>
# This Jupyter notebook is part of a series of notebooks to scrape, parse, engineer, unify, and then model, culminating in a an Expected Transfer (xTransfer) player performance vs. valuation model. This model aims to determine the under- and over-performing players based on their on-the-pitch output against transfer fee and wages.
#
# This particular notebook is one of several **data engineering** notebooks, that takes player salary data previously from the [Capology](https://www.capology.com/), and manipulates it to a clean form as Dataframes using [pandas](http://pandas.pydata.org/).
#
# This notebook, along with the other notebooks in this project workflow are shown in the following diagram:
#
# ![roadmap](../../img/football_analytics_data_roadmap.png)
#
# Links to these notebooks in the [`football_analytics`](https://github.com/eddwebster/football_analytics) GitHub repository can be found at the following:
# *    [Webscraping](https://github.com/eddwebster/football_analytics/tree/master/notebooks/1_data_scraping)
#      +    [FBref Player Stats Webscraping](https://github.com/eddwebster/football_analytics/blob/master/notebooks/1_data_scraping/FBref%20Player%20Stats%20Web%20Scraping.ipynb)
#      +    [TransferMarket Player Bio and Status Webscraping](https://github.com/eddwebster/football_analytics/blob/master/notebooks/1_data_scraping/TransferMarkt%20Player%20Bio%20and%20Status%20Web%20Scraping.ipynb)
#      +    [TransferMarkt Player Recorded Transfer Fees Webscraping](https://github.com/eddwebster/football_analytics/blob/master/notebooks/1_data_scraping/TransferMarkt%20Player%20Recorded%20Transfer%20Fees%20Webscraping.ipynb)
#      +    [Capology Player Salary Webscraping](https://github.com/eddwebster/football_analytics/blob/master/notebooks/1_data_scraping/Capology%20Player%20Salary%20Web%20Scraping.ipynb)
#      +    [FBref Team Stats Webscraping](https://github.com/eddwebster/football_analytics/blob/master/notebooks/1_data_scraping/FBref%20Team%20Stats%20Web%20Scraping.ipynb)
# *    [Data Parsing](https://github.com/eddwebster/football_analytics/tree/master/notebooks/2_data_parsing)
#      +    [ELO Team Ratings Data Parsing](https://github.com/eddwebster/football_analytics/blob/master/notebooks/2_data_parsing/ELO%20Team%20Ratings%20Data%20Parsing.ipynb)
# *    [Data Engineering](https://github.com/eddwebster/football_analytics/tree/master/notebooks/3_data_engineering)
#      +    [FBref Player Stats Data Engineering](https://github.com/eddwebster/football_analytics/blob/master/notebooks/3_data_engineering/FBref%20Player%20Stats%20Data%20Engineering.ipynb)
#      +    [TransferMarket Player Bio and Status Data Engineering](https://github.com/eddwebster/football_analytics/blob/master/notebooks/3_data_engineering/TransferMarkt%20Player%20Bio%20and%20Status%20Data%20Engineering.ipynb)
#      +    [TransferMarkt Player Recorded Transfer Fees Data Engineering](https://github.com/eddwebster/football_analytics/blob/master/notebooks/3_data_engineering/TransferMarkt%20Player%20Recorded%20Transfer%20Fees%20Data%20Engineering.ipynb)
#      +    [Capology Player Salary Data Engineering](https://github.com/eddwebster/football_analytics/blob/master/notebooks/3_data_engineering/Capology%20Player%20Salary%20Data%20Engineering.ipynb)
#      +    [FBref Team Stats Data Engineering](https://github.com/eddwebster/football_analytics/blob/master/notebooks/3_data_engineering/FBref%20Team%20Stats%20Data%20Engineering.ipynb)
#      +    [ELO Team Ratings Data Parsing](https://github.com/eddwebster/football_analytics/blob/master/notebooks/3_data_engineering/ELO%20Team%20Ratings%20Data%20Parsing.ipynb)
#      +    [TransferMarkt Team Recorded Transfer Fee Data Engineering](https://github.com/eddwebster/football_analytics/blob/master/notebooks/3_data_engineering/TransferMarkt%20Team%20Recorded%20Transfer%20Fee%20Data%20Engineering.ipynb) (aggregated from [TransferMarkt Player Recorded Transfer Fees notebook](https://github.com/eddwebster/football_analytics/blob/master/notebooks/3_data_engineering/TransferMarkt%20Player%20Recorded%20Transfer%20Fees%20Data%20Engineering.ipynb))
#      +    [Capology Team Salary Data Engineering](https://github.com/eddwebster/football_analytics/blob/master/notebooks/3_data_engineering/Capology%20Team%20Salary%20Data%20Engineering.ipynb) (aggregated from [Capology Player Salary notebook](https://github.com/eddwebster/football_analytics/blob/master/notebooks/3_data_engineering/Capology%20Player%20Salary%20Data%20Engineering.ipynb))
# *    [Data Unification](https://github.com/eddwebster/football_analytics/tree/master/notebooks/4_data_unification)
#      +    [Golden ID for Player Level Datasets](https://github.com/eddwebster/football_analytics/blob/master/notebooks/4_data_unification/Golden%20ID%20for%20Player%20Level%20Datasets.ipynb)
#      +    [Golden ID for Team Level Datasets](https://github.com/eddwebster/football_analytics/blob/master/notebooks/4_data_unification/Golden%20ID%20for%20Team%20Level%20Datasets.ipynb)
# *    [Production Datasets](https://github.com/eddwebster/football_analytics/tree/master/notebooks/5_production_datasets)
#      +    [Player Performance/Market Value Dataset](https://github.com/eddwebster/football_analytics/tree/master/notebooks/5_production_datasets/Player%20Performance/Market%20Value%20Dataset.ipynb)
#      +    [Team Performance/Market Value Dataset](https://github.com/eddwebster/football_analytics/tree/master/notebooks/5_production_datasets/Team%20Performance/Market%20Value%20Dataset.ipynb)
# *    [Expected Transfer (xTransfer) Modeling](https://github.com/eddwebster/football_analytics/tree/master/notebooks/6_data_analysis_and_projects/expected_transfer_modeling)
#      +    [Expected Transfer (xTransfer) Modeling](https://github.com/eddwebster/football_analytics/tree/master/notebooks/6_data_analysis_and_projects/expected_transfer_modeling/Expected%20Transfer%20%20Modeling.ipynb)
#
# **Notebook Conventions**:<br>
# *    Variables that refer a `DataFrame` object are prefixed with `df_`.
# *    Variables that refer to a collection of `DataFrame` objects (e.g., a list, a set or a dict) are prefixed with `dfs_`.

# %% [markdown]
# ---
#
# <a id='section3'></a>
#
# ## <a id='#section3'>3. Data Sources</a>

# %% [markdown]
# ### <a id='#section3.1'>3.1. Introduction</a>
# ...

# %% [markdown]
# ### <a id='#section3.2'>3.2. Data Dictionary</a>
#
# The raw dataset has one hundred and eighty eight features (columns) with the following definitions and data types:
#
# | Variable     | Data Type    | Description    |
# |------|-----|-----|
# | `squad`    | object    | ...    |
# | `players_used`    | float64    | ...    |
#
# <br>
#
# The features will be cleaned, converted and also additional features will be created in the [Data Engineering](#section4) section (Section 4).

# %% [markdown]
# ### <a id='#section3.3'>3.3. Read in CSV as pandas DataFrame</a>
# The following cell reads the the `CSV` file as a pandas `DataFrame`.

# %%
# Read data directory
print(glob.glob(os.path.join(data_dir_capology, 'raw/*.csv')))
# Out:
# ['../../data/capology/raw/capology_all_latest.csv']

# %%
# Import data as a pandas DataFrame, df_capology_raw
df_capology_raw = pd.read_csv(data_dir_capology + '/raw/capology_all_latest.csv')

# %% [markdown]
# ### <a id='#section3.4'>3.4. Initial Data Handling</a>

# %% [markdown]
# #### <a id='#section3.4.1'>3.4.1. Summary Report</a>
# Initial step of the data handling and Exploratory Data Analysis (EDA) is to create a quick summary report of the dataset using [pandas Profiling Report](https://github.com/pandas-profiling/pandas-profiling).

# %%
# Summary of the data using pandas Profiling Report
#pp.ProfileReport(df_capology_raw)

# %% [markdown]
# #### <a id='#section3.3.2'>3.3.2. Further Inspection</a>
# The following commands go into more bespoke summary of the dataset. Some of the commands include content covered in the [pandas Profiling](https://github.com/pandas-profiling/pandas-profiling) summary above, but using the standard [pandas](https://pandas.pydata.org/) functions and methods that most peoplem will be more familiar with.
#
# First check the quality of the dataset by looking first and last rows in pandas using the [head()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html) and [tail()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.tail.html) methods.

# %%
# Display the first five rows of the raw DataFrame, df_capology_raw
df_capology_raw.head()
# Out:
#    Unnamed: 0           Player Gross P/W(EUR) Gross P/Y(EUR) Gross P/Y(EUR).1  \
# 0           0  Ismaël Bennacer      € 135,385    € 7,040,000        € 370,000
# 1           1     Sergiño Dest      € 115,385    € 6,000,000              NaN
# 2           2   Theo Hernández       € 98,654    € 5,130,000              NaN
# 3           3     Divock Origi       € 98,654    € 5,130,000              NaN
# 4           4    Sandro Tonali       € 89,038    € 4,630,000              NaN
#
#          Signed  \
# 0  Jan 12, 2023
# 1   Sep 1, 2022
# 2  Feb 11, 2022
# 3   Jul 5, 2022
# 4   Sep 9, 2022
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027  \
# 0                                       Jun 30, 2027
# 1                                       Jun 30, 2023
# 2                                       Jun 30, 2026
# 3                                       Jun 30, 2026
# 4                                       Jun 30, 2027
#
#    Years Remaining 12345 Gross Remaining(EUR) Release Clause(EUR) Pos. DFKM  \
# 0                    5.0         € 35,200,000        € 50,000,000         M
# 1                    1.0          € 6,000,000                 NaN         D
# 2                    4.0         € 20,520,000                 NaN         D
# 3                    4.0         € 20,520,000                 NaN         F
# 4                    5.0         € 23,150,000                 NaN         M
#
#   Pos. AMCBCFCMDMGKLBLWRBRW   Age Status ReserveStarter        Country  \
# 0                        DM  25.0               Reserve        Algeria
# 1                        RB  22.0               Reserve  United States
# 2                        LB  25.0               Starter         France
# 3                        CF  27.0               Reserve        Belgium
# 4                        DM  22.0               Starter          Italy
#
#    Active  Loan      Team   League     Season Pos. AMCBCFCMDMGKLBLWRBSS  \
# 0     NaN   NaN  Ac Milan  Serie A  2022-2023                       NaN
# 1     NaN   NaN  Ac Milan  Serie A  2022-2023                       NaN
# 2     NaN   NaN  Ac Milan  Serie A  2022-2023                       NaN
# 3     NaN   NaN  Ac Milan  Serie A  2022-2023                       NaN
# 4     NaN   NaN  Ac Milan  Serie A  2022-2023                       NaN
#
#   Pos. CBCFCMDMGKLBLWRB  \
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2027  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Years Remaining 1235 Pos. AMCBCFCMDMGKLBLMRBRW Pos. AMCBCFCMDMGKLBLMRBRMSS  \
# 0                   NaN                       NaN                         NaN
# 1                   NaN                       NaN                         NaN
# 2                   NaN                       NaN                         NaN
# 3                   NaN                       NaN                         NaN
# 4                   NaN                       NaN                         NaN
#
#   Pos. AMCBCFCMDMGKLBLMLWRBRMRW Pos. CBCFCMDMGKLBLMLWRBRW  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
#
#   Pos. CBCFCMDMGKLBLWRBRW Pos. AMCBCFCMDMGKLBRBRWSS  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
#   Pos. AMCBCFCMDMGKLBLMLWRBRWSS Pos. CBCFCMDMGKLBRBRM  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Years Remaining 1234 Pos. AMCBCFCMDMGKLBLMLWRBRW Pos. AMCBCFCMDMGKLWRBRW  \
# 0                   NaN                         NaN                     NaN
# 1                   NaN                         NaN                     NaN
# 2                   NaN                         NaN                     NaN
# 3                   NaN                         NaN                     NaN
# 4                   NaN                         NaN                     NaN
#
#   Pos. AMCBCFCMDMGKLBRBRW Gross P/W(GBP) Gross P/Y(GBP) Gross P/Y(GBP).1  \
# 0                     NaN            NaN            NaN              NaN
# 1                     NaN            NaN            NaN              NaN
# 2                     NaN            NaN            NaN              NaN
# 3                     NaN            NaN            NaN              NaN
# 4                     NaN            NaN            NaN              NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Years Remaining 123456 Gross Remaining(GBP) Release Clause(GBP)  \
# 0                     NaN                  NaN                 NaN
# 1                     NaN                  NaN                 NaN
# 2                     NaN                  NaN                 NaN
# 3                     NaN                  NaN                 NaN
# 4                     NaN                  NaN                 NaN
#
#   Pos. AMCBCFDMGKLBLWRBRMRW  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028May 31, 2023  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027May 31, 2023  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Pos. AMCBCFCMGKLBLMLWRBSS  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028Jun 30, 2029Jun 30, 2030Jun 30, 2031  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Years Remaining 123456789 Pos. AMCBCFCMDMGKLBLWRBRWSS  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#   Pos. AMCBCFCMDMGKLBLMLWRBRM Pos. AMCBCFCMDMGKLBLWRBRMRW  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2029May 31, 2023  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Years Remaining 123457  \
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Years Remaining 123 Pos. CBCFCMGKLBRBRMRW Pos. AMCBCFCMDMGKLBLWRB  \
# 0                  NaN                   NaN                     NaN
# 1                  NaN                   NaN                     NaN
# 2                  NaN                   NaN                     NaN
# 3                  NaN                   NaN                     NaN
# 4                  NaN                   NaN                     NaN
#
#   Pos. AMCBCFCMDMGKLBRBRM Pos. CBCFCMDMGKLBLWRBRMRW Pos. AMCBCFDMGKLBLWRBRW  \
# 0                     NaN                       NaN                     NaN
# 1                     NaN                       NaN                     NaN
# 2                     NaN                       NaN                     NaN
# 3                     NaN                       NaN                     NaN
# 4                     NaN                       NaN                     NaN
#
#   Pos. AMCBCFCMDMGKLBLMRB  \
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
#   Contract Expiration Dec 31, 2023Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Pos. AMCBCFCMDMGKLBLWRBRM Pos. CBCFCMDMGKLBLWRBRWSS Pos. AMCBCFCMGKLBLWRBSS  \
# 0                       NaN                       NaN                     NaN
# 1                       NaN                       NaN                     NaN
# 2                       NaN                       NaN                     NaN
# 3                       NaN                       NaN                     NaN
# 4                       NaN                       NaN                     NaN
#
#   Pos. AMCBCFCMDMGKLBRBSS Pos. CBCFCMDMGKLBRBRW  \
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
#
#   Contract Expiration Jun 23, 2023Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2031  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Years Remaining 123459 Pos. AMCBCFCMGKLBLWRBRW  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                     NaN                     NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028Jun 30, 2029  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Years Remaining 1234567
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
# Display the last five rows of the raw DataFrame, df_capology_raw
df_capology_raw.tail()
# Out:
#       Unnamed: 0           Player Gross P/W(EUR) Gross P/Y(EUR)  \
# 2748         513       Pepe Reina       € 11,538      € 600,000
# 2749         514  Filip Jörgensen       € 11,538      € 600,000
# 2750         515       Álex Baena        € 9,615      € 500,000
# 2751         516   Arnaut Danjuma            € 0            € 0
# 2752         517            Total    € 1,494,805   € 77,730,000
#
#      Gross P/Y(EUR).1        Signed  \
# 2748              NaN   Jul 8, 2022
# 2749              NaN  Nov 12, 2020
# 2750              NaN  Jan 20, 2023
# 2751              NaN  Aug 19, 2021
# 2752              € 0           NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027  \
# 2748                                                NaN
# 2749                                                NaN
# 2750                                                NaN
# 2751                                                NaN
# 2752                                                NaN
#
#       Years Remaining 12345 Gross Remaining(EUR) Release Clause(EUR)  \
# 2748                    NaN            € 600,000                 NaN
# 2749                    NaN          € 1,800,000                 NaN
# 2750                    NaN          € 3,000,000                 NaN
# 2751                    NaN                  € 0                 NaN
# 2752                    NaN        € 210,870,000       € 282,000,000
#
#      Pos. DFKM Pos. AMCBCFCMDMGKLBLWRBRW   Age Status ReserveStarter  \
# 2748         K                       NaN  40.0               Starter
# 2749         K                       NaN  20.0               Reserve
# 2750         F                       NaN  21.0               Starter
# 2751         F                       NaN  26.0               Reserve
# 2752       NaN                       NaN   NaN                   NaN
#
#           Country  Active  Loan        Team   League     Season  \
# 2748        Spain     NaN   NaN  Villarreal  La Liga  2022-2023
# 2749      Denmark     NaN   NaN  Villarreal  La Liga  2022-2023
# 2750        Spain     NaN   NaN  Villarreal  La Liga  2022-2023
# 2751  Netherlands     NaN   NaN  Villarreal  La Liga  2022-2023
# 2752          NaN     NaN   NaN  Villarreal  La Liga  2022-2023
#
#      Pos. AMCBCFCMDMGKLBLWRBSS Pos. CBCFCMDMGKLBLWRB  \
# 2748                       NaN                   NaN
# 2749                       NaN                   NaN
# 2750                       NaN                   NaN
# 2751                       NaN                   NaN
# 2752                       NaN                   NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2027  \
# 2748                                                NaN
# 2749                                                NaN
# 2750                                                NaN
# 2751                                                NaN
# 2752                                                NaN
#
#       Years Remaining 1235 Pos. AMCBCFCMDMGKLBLMRBRW  \
# 2748                   NaN                       NaN
# 2749                   NaN                       NaN
# 2750                   NaN                       NaN
# 2751                   NaN                       NaN
# 2752                   NaN                       NaN
#
#      Pos. AMCBCFCMDMGKLBLMRBRMSS Pos. AMCBCFCMDMGKLBLMLWRBRMRW  \
# 2748                         NaN                           NaN
# 2749                         NaN                           NaN
# 2750                         NaN                           NaN
# 2751                         NaN                           NaN
# 2752                         NaN                           NaN
#
#      Pos. CBCFCMDMGKLBLMLWRBRW Pos. CBCFCMDMGKLBLWRBRW  \
# 2748                       NaN                      GK
# 2749                       NaN                      GK
# 2750                       NaN                      LW
# 2751                       NaN                      CF
# 2752                       NaN                     NaN
#
#      Pos. AMCBCFCMDMGKLBRBRWSS Pos. AMCBCFCMDMGKLBLMLWRBRWSS  \
# 2748                       NaN                           NaN
# 2749                       NaN                           NaN
# 2750                       NaN                           NaN
# 2751                       NaN                           NaN
# 2752                       NaN                           NaN
#
#      Pos. CBCFCMDMGKLBRBRM  \
# 2748                   NaN
# 2749                   NaN
# 2750                   NaN
# 2751                   NaN
# 2752                   NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026  \
# 2748                                                NaN
# 2749                                                NaN
# 2750                                                NaN
# 2751                                                NaN
# 2752                                                NaN
#
#       Years Remaining 1234 Pos. AMCBCFCMDMGKLBLMLWRBRW  \
# 2748                   NaN                         NaN
# 2749                   NaN                         NaN
# 2750                   NaN                         NaN
# 2751                   NaN                         NaN
# 2752                   NaN                         NaN
#
#      Pos. AMCBCFCMDMGKLWRBRW Pos. AMCBCFCMDMGKLBRBRW Gross P/W(GBP)  \
# 2748                     NaN                     NaN            NaN
# 2749                     NaN                     NaN            NaN
# 2750                     NaN                     NaN            NaN
# 2751                     NaN                     NaN            NaN
# 2752                     NaN                     NaN            NaN
#
#      Gross P/Y(GBP) Gross P/Y(GBP).1  \
# 2748            NaN              NaN
# 2749            NaN              NaN
# 2750            NaN              NaN
# 2751            NaN              NaN
# 2752            NaN              NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028  \
# 2748                                       Jun 30, 2023
# 2749                                       Jun 30, 2025
# 2750                                       Jun 30, 2028
# 2751                                       Jun 30, 2026
# 2752                                                NaN
#
#       Years Remaining 123456 Gross Remaining(GBP) Release Clause(GBP)  \
# 2748                     1.0                  NaN                 NaN
# 2749                     3.0                  NaN                 NaN
# 2750                     6.0                  NaN                 NaN
# 2751                     4.0                  NaN                 NaN
# 2752                     NaN                  NaN                 NaN
#
#      Pos. AMCBCFDMGKLBLWRBRMRW  \
# 2748                       NaN
# 2749                       NaN
# 2750                       NaN
# 2751                       NaN
# 2752                       NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028May 31, 2023  \
# 2748                                                NaN
# 2749                                                NaN
# 2750                                                NaN
# 2751                                                NaN
# 2752                                                NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027May 31, 2023  \
# 2748                                                NaN
# 2749                                                NaN
# 2750                                                NaN
# 2751                                                NaN
# 2752                                                NaN
#
#      Pos. AMCBCFCMGKLBLMLWRBSS  \
# 2748                       NaN
# 2749                       NaN
# 2750                       NaN
# 2751                       NaN
# 2752                       NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028Jun 30, 2029Jun 30, 2030Jun 30, 2031  \
# 2748                                                NaN
# 2749                                                NaN
# 2750                                                NaN
# 2751                                                NaN
# 2752                                                NaN
#
#       Years Remaining 123456789 Pos. AMCBCFCMDMGKLBLWRBRWSS  \
# 2748                        NaN                         NaN
# 2749                        NaN                         NaN
# 2750                        NaN                         NaN
# 2751                        NaN                         NaN
# 2752                        NaN                         NaN
#
#      Pos. AMCBCFCMDMGKLBLMLWRBRM Pos. AMCBCFCMDMGKLBLWRBRMRW  \
# 2748                         NaN                         NaN
# 2749                         NaN                         NaN
# 2750                         NaN                         NaN
# 2751                         NaN                         NaN
# 2752                         NaN                         NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2029May 31, 2023  \
# 2748                                                NaN
# 2749                                                NaN
# 2750                                                NaN
# 2751                                                NaN
# 2752                                                NaN
#
#       Years Remaining 123457  \
# 2748                     NaN
# 2749                     NaN
# 2750                     NaN
# 2751                     NaN
# 2752                     NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025  \
# 2748                                                NaN
# 2749                                                NaN
# 2750                                                NaN
# 2751                                                NaN
# 2752                                                NaN
#
#       Years Remaining 123 Pos. CBCFCMGKLBRBRMRW Pos. AMCBCFCMDMGKLBLWRB  \
# 2748                  NaN                   NaN                     NaN
# 2749                  NaN                   NaN                     NaN
# 2750                  NaN                   NaN                     NaN
# 2751                  NaN                   NaN                     NaN
# 2752                  NaN                   NaN                     NaN
#
#      Pos. AMCBCFCMDMGKLBRBRM Pos. CBCFCMDMGKLBLWRBRMRW  \
# 2748                     NaN                       NaN
# 2749                     NaN                       NaN
# 2750                     NaN                       NaN
# 2751                     NaN                       NaN
# 2752                     NaN                       NaN
#
#      Pos. AMCBCFDMGKLBLWRBRW Pos. AMCBCFCMDMGKLBLMRB  \
# 2748                     NaN                     NaN
# 2749                     NaN                     NaN
# 2750                     NaN                     NaN
# 2751                     NaN                     NaN
# 2752                     NaN                     NaN
#
#      Contract Expiration Dec 31, 2023Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027  \
# 2748                                                NaN
# 2749                                                NaN
# 2750                                                NaN
# 2751                                                NaN
# 2752                                                NaN
#
#      Pos. AMCBCFCMDMGKLBLWRBRM Pos. CBCFCMDMGKLBLWRBRWSS  \
# 2748                       NaN                       NaN
# 2749                       NaN                       NaN
# 2750                       NaN                       NaN
# 2751                       NaN                       NaN
# 2752                       NaN                       NaN
#
#      Pos. AMCBCFCMGKLBLWRBSS Pos. AMCBCFCMDMGKLBRBSS Pos. CBCFCMDMGKLBRBRW  \
# 2748                     NaN                     NaN                   NaN
# 2749                     NaN                     NaN                   NaN
# 2750                     NaN                     NaN                   NaN
# 2751                     NaN                     NaN                   NaN
# 2752                     NaN                     NaN                   NaN
#
#      Contract Expiration Jun 23, 2023Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027  \
# 2748                                                NaN
# 2749                                                NaN
# 2750                                                NaN
# 2751                                                NaN
# 2752                                                NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2031  \
# 2748                                                NaN
# 2749                                                NaN
# 2750                                                NaN
# 2751                                                NaN
# 2752                                                NaN
#
#       Years Remaining 123459 Pos. AMCBCFCMGKLBLWRBRW  \
# 2748                     NaN                     NaN
# 2749                     NaN                     NaN
# 2750                     NaN                     NaN
# 2751                     NaN                     NaN
# 2752                     NaN                     NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028Jun 30, 2029  \
# 2748                                                NaN
# 2749                                                NaN
# 2750                                                NaN
# 2751                                                NaN
# 2752                                                NaN
#
#       Years Remaining 1234567
# 2748                      NaN
# 2749                      NaN
# 2750                      NaN
# 2751                      NaN
# 2752                      NaN

# %%
# Print the shape of the raw DataFrame, df_capology_raw
print(df_capology_raw.shape)
# Out:
# (2753, 75)

# %%
# Print the column names of the raw DataFrame, df_capology_raw
print(df_capology_raw.columns)
# Out:
# Index(['Unnamed: 0', 'Player', 'Gross P/W(EUR)', 'Gross P/Y(EUR)',
#        'Gross P/Y(EUR).1', 'Signed',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027',
#        'Years Remaining 12345', 'Gross Remaining(EUR)', 'Release Clause(EUR)',
#        'Pos. DFKM', 'Pos. AMCBCFCMDMGKLBLWRBRW', 'Age',
#        'Status ReserveStarter', 'Country', 'Active', 'Loan', 'Team', 'League',
#        'Season', 'Pos. AMCBCFCMDMGKLBLWRBSS', 'Pos. CBCFCMDMGKLBLWRB',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2027',
#        'Years Remaining 1235', 'Pos. AMCBCFCMDMGKLBLMRBRW',
#        'Pos. AMCBCFCMDMGKLBLMRBRMSS', 'Pos. AMCBCFCMDMGKLBLMLWRBRMRW',
#        'Pos. CBCFCMDMGKLBLMLWRBRW', 'Pos. CBCFCMDMGKLBLWRBRW',
#        'Pos. AMCBCFCMDMGKLBRBRWSS', 'Pos. AMCBCFCMDMGKLBLMLWRBRWSS',
#        'Pos. CBCFCMDMGKLBRBRM',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026',
#        'Years Remaining 1234', 'Pos. AMCBCFCMDMGKLBLMLWRBRW',
#        'Pos. AMCBCFCMDMGKLWRBRW', 'Pos. AMCBCFCMDMGKLBRBRW', 'Gross P/W(GBP)',
#        'Gross P/Y(GBP)', 'Gross P/Y(GBP).1',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028',
#        'Years Remaining 123456', 'Gross Remaining(GBP)', 'Release Clause(GBP)',
#        'Pos. AMCBCFDMGKLBLWRBRMRW',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028May 31, 2023',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027May 31, 2023',
#        'Pos. AMCBCFCMGKLBLMLWRBSS',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028Jun 30, 2029Jun 30, 2030Jun 30, 2031',
#        'Years Remaining 123456789', 'Pos. AMCBCFCMDMGKLBLWRBRWSS',
#        'Pos. AMCBCFCMDMGKLBLMLWRBRM', 'Pos. AMCBCFCMDMGKLBLWRBRMRW',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2029May 31, 2023',
#        'Years Remaining 123457',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025',
#        'Years Remaining 123', 'Pos. CBCFCMGKLBRBRMRW',
#        'Pos. AMCBCFCMDMGKLBLWRB', 'Pos. AMCBCFCMDMGKLBRBRM',
#        'Pos. CBCFCMDMGKLBLWRBRMRW', 'Pos. AMCBCFDMGKLBLWRBRW',
#        'Pos. AMCBCFCMDMGKLBLMRB',
#        'Contract Expiration Dec 31, 2023Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027',
#        'Pos. AMCBCFCMDMGKLBLWRBRM', 'Pos. CBCFCMDMGKLBLWRBRWSS',
#        'Pos. AMCBCFCMGKLBLWRBSS', 'Pos. AMCBCFCMDMGKLBRBSS',
#        'Pos. CBCFCMDMGKLBRBRW',
#        'Contract Expiration Jun 23, 2023Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2031',
#        'Years Remaining 123459', 'Pos. AMCBCFCMGKLBLWRBRW',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028Jun 30, 2029',
#        'Years Remaining 1234567'],
#       dtype='object')

# %% [markdown]
# The dataset has ten features (columns). Full details of these attributes can be found in the [Data Dictionary](section3.3.1).

# %%
# Data types of the features of the raw DataFrame, df_capology_raw
df_capology_raw.dtypes
# Out:
# Unnamed: 0                                                                                                    int64
# Player                                                                                                       object
# Gross P/W(EUR)                                                                                               object
# Gross P/Y(EUR)                                                                                               object
# Gross P/Y(EUR).1                                                                                             object
#                                                                                                              ...
# Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2031                 object
# Years Remaining 123459                                                                                      float64
# Pos. AMCBCFCMGKLBLWRBRW                                                                                      object
# Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028Jun 30, 2029     object
# Years Remaining 1234567                                                                                     float64
# Length: 75, dtype: object

# %%
# Info for the raw DataFrame, df_capology_raw
df_capology_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2753 entries, 0 to 2752
# Data columns (total 75 columns):
#  #   Column                                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                                            --------------  -----
#  0   Unnamed: 0                                                                                                                        2753 non-null   int64
#  1   Player                                                                                                                            2753 non-null   object
#  2   Gross P/W(EUR)                                                                                                                    2200 non-null   object
#  3   Gross P/Y(EUR)                                                                                                                    2200 non-null   object
#  4   Gross P/Y(EUR).1                                                                                                                  124 non-null    object
#  5   Signed                                                                                                                            2643 non-null   object
#  6   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027                                                  1428 non-null   object
#  7   Years Remaining 12345                                                                                                             1588 non-null   float64
#  8   Gross Remaining(EUR)                                                                                                              2200 non-null   object
#  9   Release Clause(EUR)                                                                                                               151 non-null    object
#  10  Pos. DFKM                                                                                                                         2655 non-null   object
#  11  Pos. AMCBCFCMDMGKLBLWRBRW                                                                                                         1028 non-null   object
#  12  Age                                                                                                                               2655 non-null   float64
#  13  Status ReserveStarter                                                                                                             2655 non-null   object
#  14  Country                                                                                                                           2655 non-null   object
#  15  Active                                                                                                                            0 non-null      float64
#  16  Loan                                                                                                                              0 non-null      float64
#  17  Team                                                                                                                              2753 non-null   object
#  18  League                                                                                                                            2753 non-null   object
#  19  Season                                                                                                                            2753 non-null   object
#  20  Pos. AMCBCFCMDMGKLBLWRBSS                                                                                                         61 non-null     object
#  21  Pos. CBCFCMDMGKLBLWRB                                                                                                             26 non-null     object
#  22  Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2027                                                              56 non-null     object
#  23  Years Remaining 1235                                                                                                              56 non-null     float64
#  24  Pos. AMCBCFCMDMGKLBLMRBRW                                                                                                         29 non-null     object
#  25  Pos. AMCBCFCMDMGKLBLMRBRMSS                                                                                                       28 non-null     object
#  26  Pos. AMCBCFCMDMGKLBLMLWRBRMRW                                                                                                     59 non-null     object
#  27  Pos. CBCFCMDMGKLBLMLWRBRW                                                                                                         53 non-null     object
#  28  Pos. CBCFCMDMGKLBLWRBRW                                                                                                           203 non-null    object
#  29  Pos. AMCBCFCMDMGKLBRBRWSS                                                                                                         58 non-null     object
#  30  Pos. AMCBCFCMDMGKLBLMLWRBRWSS                                                                                                     80 non-null     object
#  31  Pos. CBCFCMDMGKLBRBRM                                                                                                             28 non-null     object
#  32  Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026                                                              293 non-null    object
#  33  Years Remaining 1234                                                                                                              293 non-null    float64
#  34  Pos. AMCBCFCMDMGKLBLMLWRBRW                                                                                                       62 non-null     object
#  35  Pos. AMCBCFCMDMGKLWRBRW                                                                                                           28 non-null     object
#  36  Pos. AMCBCFCMDMGKLBRBRW                                                                                                           49 non-null     object
#  37  Gross P/W(GBP)                                                                                                                    553 non-null    object
#  38  Gross P/Y(GBP)                                                                                                                    553 non-null    object
#  39  Gross P/Y(GBP).1                                                                                                                  33 non-null     object
#  40  Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028                                      512 non-null    object
#  41  Years Remaining 123456                                                                                                            539 non-null    float64
#  42  Gross Remaining(GBP)                                                                                                              553 non-null    object
#  43  Release Clause(GBP)                                                                                                               22 non-null     object
#  44  Pos. AMCBCFDMGKLBLWRBRMRW                                                                                                         23 non-null     object
#  45  Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028May 31, 2023                          27 non-null     object
#  46  Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027May 31, 2023                                      102 non-null    object
#  47  Pos. AMCBCFCMGKLBLMLWRBSS                                                                                                         24 non-null     object
#  48  Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028Jun 30, 2029Jun 30, 2030Jun 30, 2031  32 non-null     object
#  49  Years Remaining 123456789                                                                                                         32 non-null     float64
#  50  Pos. AMCBCFCMDMGKLBLWRBRWSS                                                                                                       159 non-null    object
#  51  Pos. AMCBCFCMDMGKLBLMLWRBRM                                                                                                       24 non-null     object
#  52  Pos. AMCBCFCMDMGKLBLWRBRMRW                                                                                                       210 non-null    object
#  53  Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2029May 31, 2023                          37 non-null     object
#  54  Years Remaining 123457                                                                                                            37 non-null     float64
#  55  Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025                                                                          63 non-null     object
#  56  Years Remaining 123                                                                                                               63 non-null     float64
#  57  Pos. CBCFCMGKLBRBRMRW                                                                                                             26 non-null     object
#  58  Pos. AMCBCFCMDMGKLBLWRB                                                                                                           100 non-null    object
#  59  Pos. AMCBCFCMDMGKLBRBRM                                                                                                           29 non-null     object
#  60  Pos. CBCFCMDMGKLBLWRBRMRW                                                                                                         27 non-null     object
#  61  Pos. AMCBCFDMGKLBLWRBRW                                                                                                           21 non-null     object
#  62  Pos. AMCBCFCMDMGKLBLMRB                                                                                                           25 non-null     object
#  63  Contract Expiration Dec 31, 2023Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027                                      32 non-null     object
#  64  Pos. AMCBCFCMDMGKLBLWRBRM                                                                                                         31 non-null     object
#  65  Pos. CBCFCMDMGKLBLWRBRWSS                                                                                                         61 non-null     object
#  66  Pos. AMCBCFCMGKLBLWRBSS                                                                                                           27 non-null     object
#  67  Pos. AMCBCFCMDMGKLBRBSS                                                                                                           26 non-null     object
#  68  Pos. CBCFCMDMGKLBRBRW                                                                                                             25 non-null     object
#  69  Contract Expiration Jun 23, 2023Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027                                      26 non-null     object
#  70  Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2031                                      21 non-null     object
#  71  Years Remaining 123459                                                                                                            21 non-null     float64
#  72  Pos. AMCBCFCMGKLBLWRBRW                                                                                                           25 non-null     object
#  73  Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028Jun 30, 2029                          26 non-null     object
#  74  Years Remaining 1234567                                                                                                           26 non-null     float64
# dtypes: float64(12), int64(1), object(62)
# memory usage: 1.6+ MB

# %%
# Description of the raw DataFrame, df_capology_raw, showing some summary statistics for each numerical column in the DataFrame
df_capology_raw.describe()
# Out:
#         Unnamed: 0  Years Remaining 12345          Age  Active  Loan  \
# count  2753.000000            1588.000000  2655.000000     0.0   0.0
# mean    275.278242               2.618388    26.018832     NaN   NaN
# std     159.803123               1.376448     4.627864     NaN   NaN
# min       0.000000               1.000000    16.000000     NaN   NaN
# 25%     137.000000               1.000000    22.000000     NaN   NaN
# 50%     275.000000               3.000000    26.000000     NaN   NaN
# 75%     412.000000               4.000000    29.000000     NaN   NaN
# max     586.000000               5.000000    41.000000     NaN   NaN
#
#        Years Remaining 1235  Years Remaining 1234  Years Remaining 123456  \
# count             56.000000            293.000000              539.000000
# mean               1.660714              2.221843                3.037106
# std                1.116436              1.095727                1.557604
# min                1.000000              1.000000                1.000000
# 25%                1.000000              1.000000                2.000000
# 50%                1.000000              2.000000                3.000000
# 75%                2.000000              3.000000                4.000000
# max                5.000000              4.000000                6.000000
#
#        Years Remaining 123456789  Years Remaining 123457  Years Remaining 123  \
# count                  32.000000               37.000000            63.000000
# mean                    4.125000                2.567568             1.682540
# std                     2.511265                1.500751             0.799706
# min                     1.000000                1.000000             1.000000
# 25%                     2.000000                1.000000             1.000000
# 50%                     3.000000                2.000000             1.000000
# 75%                     6.000000                4.000000             2.000000
# max                     9.000000                7.000000             3.000000
#
#        Years Remaining 123459  Years Remaining 1234567
# count               21.000000                26.000000
# mean                 3.095238                 3.115385
# std                  1.894855                 1.583084
# min                  1.000000                 1.000000
# 25%                  2.000000                 2.000000
# 50%                  3.000000                 3.000000
# 75%                  4.000000                 4.000000
# max                  9.000000                 7.000000

# %%
# Plot visualisation of the missing values for each feature of the raw DataFrame, df_capology_raw
msno.matrix(df_capology_raw, figsize = (30, 7))
# Out:
# <AxesSubplot: >

# %%
# Counts of missing values
null_value_stats = df_capology_raw.isnull().sum(axis=0)
null_value_stats[null_value_stats != 0]
# Out:
# Gross P/W(EUR)                                                                                               553
# Gross P/Y(EUR)                                                                                               553
# Gross P/Y(EUR).1                                                                                            2629
# Signed                                                                                                       110
# Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027                            1325
#                                                                                                             ...
# Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2031                2732
# Years Remaining 123459                                                                                      2732
# Pos. AMCBCFCMGKLBLWRBRW                                                                                     2728
# Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028Jun 30, 2029    2727
# Years Remaining 1234567                                                                                     2727
# Length: 70, dtype: int64

# %% [markdown]
# The visualisation shows us very quickly that there are missing values in a number of the columns, such as the financial columns such as Estimated Gross Total. This is because depending on the country, the financial values are only scraped in one country. This need to be coalesced.
#
# This concludes the data handling section, the next thing to do is engineer the raw dataset to be ready for further analysis.

# %% [markdown]
# ---
#
# ## <a id='#section4'>4. Data Engineering</a>
# Before any Data Analysis, we first need to clean and wrangle the datasets to a form that meet our needs.

# %% [markdown]
# Still to add:
# - Original value columns

# %% [markdown]
# ### <a id='#section4.1'>4.1. Assign Raw DataFrame to Engineered DataFrame
# From this point, all changes made to the dataset applied to the new engineered DataFrame, `df_capology`.

# %%
# Assign Raw DataFrame to Engineered DataFrame
df_capology = df_capology_raw.copy()

# df_capology = df_capology.iloc[:, 1:20]

# Display DataFrame
df_capology.head()
# Out:
#    Unnamed: 0           Player Gross P/W(EUR) Gross P/Y(EUR) Gross P/Y(EUR).1  \
# 0           0  Ismaël Bennacer      € 135,385    € 7,040,000        € 370,000
# 1           1     Sergiño Dest      € 115,385    € 6,000,000              NaN
# 2           2   Theo Hernández       € 98,654    € 5,130,000              NaN
# 3           3     Divock Origi       € 98,654    € 5,130,000              NaN
# 4           4    Sandro Tonali       € 89,038    € 4,630,000              NaN
#
#          Signed  \
# 0  Jan 12, 2023
# 1   Sep 1, 2022
# 2  Feb 11, 2022
# 3   Jul 5, 2022
# 4   Sep 9, 2022
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027  \
# 0                                       Jun 30, 2027
# 1                                       Jun 30, 2023
# 2                                       Jun 30, 2026
# 3                                       Jun 30, 2026
# 4                                       Jun 30, 2027
#
#    Years Remaining 12345 Gross Remaining(EUR) Release Clause(EUR) Pos. DFKM  \
# 0                    5.0         € 35,200,000        € 50,000,000         M
# 1                    1.0          € 6,000,000                 NaN         D
# 2                    4.0         € 20,520,000                 NaN         D
# 3                    4.0         € 20,520,000                 NaN         F
# 4                    5.0         € 23,150,000                 NaN         M
#
#   Pos. AMCBCFCMDMGKLBLWRBRW   Age Status ReserveStarter        Country  \
# 0                        DM  25.0               Reserve        Algeria
# 1                        RB  22.0               Reserve  United States
# 2                        LB  25.0               Starter         France
# 3                        CF  27.0               Reserve        Belgium
# 4                        DM  22.0               Starter          Italy
#
#    Active  Loan      Team   League     Season Pos. AMCBCFCMDMGKLBLWRBSS  \
# 0     NaN   NaN  Ac Milan  Serie A  2022-2023                       NaN
# 1     NaN   NaN  Ac Milan  Serie A  2022-2023                       NaN
# 2     NaN   NaN  Ac Milan  Serie A  2022-2023                       NaN
# 3     NaN   NaN  Ac Milan  Serie A  2022-2023                       NaN
# 4     NaN   NaN  Ac Milan  Serie A  2022-2023                       NaN
#
#   Pos. CBCFCMDMGKLBLWRB  \
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2027  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Years Remaining 1235 Pos. AMCBCFCMDMGKLBLMRBRW Pos. AMCBCFCMDMGKLBLMRBRMSS  \
# 0                   NaN                       NaN                         NaN
# 1                   NaN                       NaN                         NaN
# 2                   NaN                       NaN                         NaN
# 3                   NaN                       NaN                         NaN
# 4                   NaN                       NaN                         NaN
#
#   Pos. AMCBCFCMDMGKLBLMLWRBRMRW Pos. CBCFCMDMGKLBLMLWRBRW  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
#
#   Pos. CBCFCMDMGKLBLWRBRW Pos. AMCBCFCMDMGKLBRBRWSS  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
#   Pos. AMCBCFCMDMGKLBLMLWRBRWSS Pos. CBCFCMDMGKLBRBRM  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Years Remaining 1234 Pos. AMCBCFCMDMGKLBLMLWRBRW Pos. AMCBCFCMDMGKLWRBRW  \
# 0                   NaN                         NaN                     NaN
# 1                   NaN                         NaN                     NaN
# 2                   NaN                         NaN                     NaN
# 3                   NaN                         NaN                     NaN
# 4                   NaN                         NaN                     NaN
#
#   Pos. AMCBCFCMDMGKLBRBRW Gross P/W(GBP) Gross P/Y(GBP) Gross P/Y(GBP).1  \
# 0                     NaN            NaN            NaN              NaN
# 1                     NaN            NaN            NaN              NaN
# 2                     NaN            NaN            NaN              NaN
# 3                     NaN            NaN            NaN              NaN
# 4                     NaN            NaN            NaN              NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Years Remaining 123456 Gross Remaining(GBP) Release Clause(GBP)  \
# 0                     NaN                  NaN                 NaN
# 1                     NaN                  NaN                 NaN
# 2                     NaN                  NaN                 NaN
# 3                     NaN                  NaN                 NaN
# 4                     NaN                  NaN                 NaN
#
#   Pos. AMCBCFDMGKLBLWRBRMRW  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028May 31, 2023  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027May 31, 2023  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Pos. AMCBCFCMGKLBLMLWRBSS  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028Jun 30, 2029Jun 30, 2030Jun 30, 2031  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Years Remaining 123456789 Pos. AMCBCFCMDMGKLBLWRBRWSS  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#   Pos. AMCBCFCMDMGKLBLMLWRBRM Pos. AMCBCFCMDMGKLBLWRBRMRW  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2029May 31, 2023  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Years Remaining 123457  \
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Years Remaining 123 Pos. CBCFCMGKLBRBRMRW Pos. AMCBCFCMDMGKLBLWRB  \
# 0                  NaN                   NaN                     NaN
# 1                  NaN                   NaN                     NaN
# 2                  NaN                   NaN                     NaN
# 3                  NaN                   NaN                     NaN
# 4                  NaN                   NaN                     NaN
#
#   Pos. AMCBCFCMDMGKLBRBRM Pos. CBCFCMDMGKLBLWRBRMRW Pos. AMCBCFDMGKLBLWRBRW  \
# 0                     NaN                       NaN                     NaN
# 1                     NaN                       NaN                     NaN
# 2                     NaN                       NaN                     NaN
# 3                     NaN                       NaN                     NaN
# 4                     NaN                       NaN                     NaN
#
#   Pos. AMCBCFCMDMGKLBLMRB  \
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
#   Contract Expiration Dec 31, 2023Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Pos. AMCBCFCMDMGKLBLWRBRM Pos. CBCFCMDMGKLBLWRBRWSS Pos. AMCBCFCMGKLBLWRBSS  \
# 0                       NaN                       NaN                     NaN
# 1                       NaN                       NaN                     NaN
# 2                       NaN                       NaN                     NaN
# 3                       NaN                       NaN                     NaN
# 4                       NaN                       NaN                     NaN
#
#   Pos. AMCBCFCMDMGKLBRBSS Pos. CBCFCMDMGKLBRBRW  \
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
#
#   Contract Expiration Jun 23, 2023Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2031  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Years Remaining 123459 Pos. AMCBCFCMGKLBLWRBRW  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                     NaN                     NaN
#
#   Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028Jun 30, 2029  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Years Remaining 1234567
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %% [markdown]
# ### <a id='#section4.2'>4.2. Clean Data

# %%
df_capology['Weekly GrossBase Salary(IN EUR)'] =  (df_capology['Gross P/W(EUR)']
                                                          .replace('None', np.nan)
                                                          .astype(str)
                                                          .str.replace('£','')
                                                          .str.replace('€','')
                                                          .str.replace('$','')
                                                          .str.replace(',','')
                                                          .str.extract('(\d+)', expand=False)
                                                     ).astype(float)
# Out:
# <ipython-input-157-43495d4ff2e1>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_capology['Weekly GrossBase Salary(IN EUR)'] =  (df_capology['Gross P/W(EUR)']

# %%
df_capology['Weekly GrossBase Salary(IN EUR)'] =  (df_capology['Gross P/W(EUR)']
                                                          .replace('None', np.nan)
                                                          .astype(str)
                                                          .str.replace('£','')
                                                          .str.replace('€','')
                                                          .str.replace('$','')
                                                          .str.replace(',','')
                                                          .str.extract('(\d+)', expand=False)
                                                     ).astype(float)

df_capology['Annual GrossBase Salary(IN EUR)'] = (df_capology['Gross P/Y(EUR)']
                                                          .replace('None', np.nan)
                                                          .astype(str)
                                                          .str.replace('£','')
                                                          .str.replace('€','')
                                                          .str.replace('$','')
                                                          .str.replace(',','')
                                                          .str.extract('(\d+)', expand=False)
                                                     ).astype(float)

df_capology['EstimatedGross Total(IN EUR)'] = (df_capology['Gross Remaining(EUR)']
                                                      .replace('None', np.nan)
                                                      .astype(str)
                                                      .str.replace('£','')
                                                      .str.replace('€','')
                                                      .str.replace('$','')
                                                      .str.replace(',','')
                                                      .str.extract('(\d+)', expand=False)
                                                 ).astype(float)

df_capology['Adj. GrossBase Salary(2021, IN EUR)'] = (df_capology['Gross P/Y(EUR).1']
                                                             .replace('None', np.nan)
                                                             .astype(str)
                                                             .str.replace('£','')
                                                             .str.replace('€','')
                                                             .str.replace('$','')
                                                             .str.replace(',','')
                                                             .str.extract('(\d+)', expand=False)
                                                        ).astype(float)

# df_capology['Weekly GrossBase Salary(IN USD)'] = (df_capology['Weekly GrossBase Salary(IN USD)']
#                                                          .replace('None', np.nan)
#                                                          .astype(str)
#                                                          .str.replace('£','')
#                                                          .str.replace('€','')
#                                                          .str.replace('$','')
#                                                          .str.replace(',','')
#                                                          .str.extract('(\d+)', expand=False)
#                                                     ).astype(float)

# df_capology['Annual GrossBase Salary(IN USD)'] = (df_capology['Annual GrossBase Salary(IN USD)']
#                                                           .replace('None', np.nan)
#                                                           .astype(str)
#                                                           .str.replace('£','')
#                                                           .str.replace('€','')
#                                                           .str.replace('$','')
#                                                           .str.replace(',','')
#                                                           .str.extract('(\d+)', expand=False)
#                                                      ).astype(float)

# df_capology['EstimatedGross Total(IN USD)'] = (df_capology['EstimatedGross Total(IN USD)']
#                                                       .replace('None', np.nan)
#                                                       .astype(str)
#                                                       .str.replace('£','')
#                                                       .str.replace('€','')
#                                                       .str.replace('$','')
#                                                       .str.replace(',','')
#                                                       .str.extract('(\d+)', expand=False)
#                                                  ).astype(float)

# df_capology['Adj. GrossBase Salary(2021, IN USD)'] = (df_capology['Adj. GrossBase Salary(2021, IN USD)']
#                                                               .replace('None', np.nan)
#                                                               .astype(str)
#                                                               .str.replace('£','')
#                                                               .str.replace('€','')
#                                                               .str.replace('$','')
#                                                               .str.replace(',','')
#                                                               .str.extract('(\d+)', expand=False)
#                                                          ).astype(float)

df_capology['Weekly GrossBase Salary(IN GBP)'] = (df_capology['Gross P/W(GBP)']
                                                          .replace('None', np.nan)
                                                          .astype(str)
                                                          .str.replace('£','')
                                                          .str.replace('€','')
                                                          .str.replace('$','')
                                                          .str.replace(',','')
                                                          .str.extract('(\d+)', expand=False)
                                                     ).astype(float)

df_capology['Annual GrossBase Salary(IN GBP)'] = (df_capology['Gross P/Y(GBP)']
                                                          .replace('None', np.nan)
                                                          .astype(str)
                                                          .str.replace('£','')
                                                          .str.replace('€','')
                                                          .str.replace('$','')
                                                          .str.replace(',','')
                                                          .str.extract('(\d+)', expand=False)
                                                     ).astype(float)

df_capology['EstimatedGross Total(IN GBP)'] = (df_capology['Gross Remaining(GBP)']
                                                      .replace('None', np.nan)
                                                      .astype(str)
                                                      .str.replace('£','')
                                                      .str.replace('€','')
                                                      .str.replace('$','')
                                                      .str.replace(',','')
                                                      .str.extract('(\d+)', expand=False)
                                                 ).astype(float)

df_capology['Adj. GrossBase Salary(2021, IN GBP)'] = (df_capology['Gross P/Y(GBP).1']
                                                              .replace('None', np.nan)
                                                              .astype(str)
                                                              .str.replace('£','')
                                                              .str.replace('€','')
                                                              .str.replace('$','')
                                                              .str.replace(',','')
                                                              .str.extract('(\d+)', expand=False)
                                                         ).astype(float)
# Out:
# <ipython-input-158-85a3a39e8025>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_capology['Weekly GrossBase Salary(IN EUR)'] =  (df_capology['Gross P/W(EUR)']
# <ipython-input-158-85a3a39e8025>:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_capology['Annual GrossBase Salary(IN EUR)'] = (df_capology['Gross P/Y(EUR)']
# <ipython-input-158-85a3a39e8025>:21: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_capology['EstimatedGross Total(IN EUR)'] = (df_capology['Gross Remaining(EUR)']
# <ipython-input-158-85a3a39e8025>:31: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_capology['Adj. GrossBase Salary(2021, IN EUR)'] = (df_capology['Gross P/Y(EUR).1']
# <ipython-input-158-85a3a39e8025>:81: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_capology['Weekly GrossBase Salary(IN GBP)'] = (df_capology['Gross P/W(GBP)']
# <ipython-input-158-85a3a39e8025>:91: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_capology['Annual GrossBase Salary(IN GBP)'] = (df_capology['Gross P/Y(GBP)']
# <ipython-input-158-85a3a39e8025>:101: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_capology['EstimatedGross Total(IN GBP)'] = (df_capology['Gross Remaining(GBP)']
# <ipython-input-158-85a3a39e8025>:111: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_capology['Adj. GrossBase Salary(2021, IN GBP)'] = (df_capology['Gross P/Y(GBP).1']

# %%
#
df_capology['Currency'] = np.where(df_capology['Annual GrossBase Salary(IN EUR)'].notnull(), 'EUR',
                                      np.where(df_capology['Annual GrossBase Salary(IN GBP)'].notnull(), 'GBP',
                                               np.where(df_capology['Annual GrossBase Salary(IN EUR)'].notnull(), 'USD', 'n/a')
                                              )
                                     )

# %%
# Get EUR to GBP exchange rate

## Get latest currency rates
c = CurrencyConverter()

##  Get conversion rate from EUR to GBP
rate_eur_gbp = (c.convert(1, 'EUR', 'GBP'))
rate_eur_gbp

##  Get conversion rate from USD to GBP
rate_usd_gbp = (c.convert(1, 'USD', 'GBP'))
rate_usd_gbp

##  
rate_gbp_gbp = 1
rate_gbp_gbp
# Out:
# 1

# %%
df_capology['Exchange Rate'] = np.where(df_capology['Currency'] == 'EUR', rate_eur_gbp,
                                           np.where(df_capology['Currency'] == 'USD', rate_usd_gbp,
                                                     np.where(df_capology['Currency'] == 'GBP', 1, np.nan)
                                                   )
                                          )

df_capology['Exchange Rate'] = df_capology['Exchange Rate'].replace('None', np.nan).astype(float)

# %%
df_capology.columns[11]
# Out:
# 'Pos.\xa0AMCBCFCMDMGKLBLWRBRW'

# %%
df_capology.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Gross P/W(EUR)', 'Gross P/Y(EUR)',
#        'Gross P/Y(EUR).1', 'Signed',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027',
#        'Years Remaining 12345', 'Gross Remaining(EUR)', 'Release Clause(EUR)',
#        'Pos. DFKM', 'Pos. AMCBCFCMDMGKLBLWRBRW', 'Age',
#        'Status ReserveStarter', 'Country', 'Active', 'Loan', 'Team', 'League',
#        'Season', 'Pos. AMCBCFCMDMGKLBLWRBSS', 'Pos. CBCFCMDMGKLBLWRB',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2027',
#        'Years Remaining 1235', 'Pos. AMCBCFCMDMGKLBLMRBRW',
#        'Pos. AMCBCFCMDMGKLBLMRBRMSS', 'Pos. AMCBCFCMDMGKLBLMLWRBRMRW',
#        'Pos. CBCFCMDMGKLBLMLWRBRW', 'Pos. CBCFCMDMGKLBLWRBRW',
#        'Pos. AMCBCFCMDMGKLBRBRWSS', 'Pos. AMCBCFCMDMGKLBLMLWRBRWSS',
#        'Pos. CBCFCMDMGKLBRBRM',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026',
#        'Years Remaining 1234', 'Pos. AMCBCFCMDMGKLBLMLWRBRW',
#        'Pos. AMCBCFCMDMGKLWRBRW', 'Pos. AMCBCFCMDMGKLBRBRW', 'Gross P/W(GBP)',
#        'Gross P/Y(GBP)', 'Gross P/Y(GBP).1',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028',
#        'Years Remaining 123456', 'Gross Remaining(GBP)', 'Release Clause(GBP)',
#        'Pos. AMCBCFDMGKLBLWRBRMRW',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028May 31, 2023',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027May 31, 2023',
#        'Pos. AMCBCFCMGKLBLMLWRBSS',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028Jun 30, 2029Jun 30, 2030Jun 30, 2031',
#        'Years Remaining 123456789', 'Pos. AMCBCFCMDMGKLBLWRBRWSS',
#        'Pos. AMCBCFCMDMGKLBLMLWRBRM', 'Pos. AMCBCFCMDMGKLBLWRBRMRW',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2029May 31, 2023',
#        'Years Remaining 123457',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025',
#        'Years Remaining 123', 'Pos. CBCFCMGKLBRBRMRW',
#        'Pos. AMCBCFCMDMGKLBLWRB', 'Pos. AMCBCFCMDMGKLBRBRM',
#        'Pos. CBCFCMDMGKLBLWRBRMRW', 'Pos. AMCBCFDMGKLBLWRBRW',
#        'Pos. AMCBCFCMDMGKLBLMRB',
#        'Contract Expiration Dec 31, 2023Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027',
#        'Pos. AMCBCFCMDMGKLBLWRBRM', 'Pos. CBCFCMDMGKLBLWRBRWSS',
#        'Pos. AMCBCFCMGKLBLWRBSS', 'Pos. AMCBCFCMDMGKLBRBSS',
#        'Pos. CBCFCMDMGKLBRBRW',
#        'Contract Expiration Jun 23, 2023Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2031',
#        'Years Remaining 123459', 'Pos. AMCBCFCMGKLBLWRBRW',
#        'Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028Jun 30, 2029',
#        'Years Remaining 1234567', 'Weekly GrossBase Salary(IN EUR)',
#        'Annual GrossBase Salary(IN EUR)', 'EstimatedGross Total(IN EUR)',
#        'Adj. GrossBase Salary(2021, IN EUR)',
#        'Weekly GrossBase Salary(IN GBP)', 'Annual GrossBase Salary(IN GBP)',
#        'EstimatedGross Total(IN GBP)', 'Adj. GrossBase Salary(2021, IN GBP)',
#        'Currency', 'Exchange Rate'],
#       dtype='object')

# %%
df_capology = df_capology[df_capology['Player'] != 'Total']

pos_columns = []
expiration_columns = []
years_columns = []
for col in df_capology.columns:
    if "Pos." in col:
        pos_columns.append(col)
    elif "Contract" in col:
        expiration_columns.append(col)
    elif "Years" in col:
        df_capology[col] = df_capology[col].fillna('')
        df_capology[col] = df_capology[col].astype(str)
        years_columns.append(col)
        
df_capology["Expiration"] = df_capology[expiration_columns].apply(lambda x: ','.join(x.dropna()), axis=1)
df_capology["Length"] = df_capology[years_columns].apply(lambda x: ','.join(x.dropna()), axis=1)
df_capology["Pos."] = df_capology[pos_columns].apply(lambda x: ','.join(x.dropna()), axis=1)

df_capology["Length"] = df_capology["Length"].apply(lambda x: x.replace(',', ''))
df_capology["Pos."] = df_capology["Pos."].apply(lambda x: x.split(',')[1])

# %%
#

## Coalesce the four salary columns

###
df_capology['Estimated Gross Total Original'] = (df_capology['EstimatedGross Total(IN GBP)']
                                                        .combine_first(df_capology['EstimatedGross Total(IN GBP)'])
#                                                         .combine_first(df_capology['EstimatedGross Total(IN USD)'])
                                                        .replace('None', np.nan)
                                                        .astype(float)
                                                   )

df_capology['Estimated Gross Total GBP'] = (df_capology['Estimated Gross Total Original'] * df_capology['Exchange Rate'])

df_capology['Estimated Gross Total GBP'] = (df_capology['Estimated Gross Total GBP']
                                                      .fillna(-1)
                                                      .astype(int)
                                                      .astype(str)
                                                      .replace('-1', np.nan)
                                                 )

###
df_capology['Weekly Gross Base Salary Original'] = (df_capology['Weekly GrossBase Salary(IN GBP)']
                                                           .combine_first(df_capology['Weekly GrossBase Salary(IN EUR)'])
#                                                            .combine_first(df_capology['Weekly GrossBase Salary(IN USD)'])
                                                           .replace('None', np.nan)
                                                           .astype(float)
                                                      )

df_capology['Weekly Gross Base Salary GBP'] = df_capology['Weekly Gross Base Salary Original'] * df_capology['Exchange Rate']

df_capology['Weekly Gross Base Salary GBP'] = (df_capology['Weekly Gross Base Salary GBP']
                                                      .fillna(-1)
                                                      .astype(int)
                                                      .astype(str)
                                                      .replace('-1', np.nan)
                                                 )

###
df_capology['Annual Gross Base Salary Original'] = (df_capology['Annual GrossBase Salary(IN GBP)']
                                                           .combine_first(df_capology['Annual GrossBase Salary(IN EUR)'])
#                                                            .combine_first(df_capology['Annual GrossBase Salary(IN USD)'])
                                                           .replace('None', np.nan)
                                                           .astype(float)
                                                      )

df_capology['Annual Gross Base Salary GBP'] = df_capology['Annual Gross Base Salary Original'] * df_capology['Exchange Rate']

df_capology['Annual Gross Base Salary GBP'] = (df_capology['Annual Gross Base Salary GBP']
                                                      .fillna(-1)
                                                      .astype(int)
                                                      .astype(str)
                                                      .replace('-1', np.nan)
                                                 )

###
df_capology['Adj. Gross Base Salary for Current Season Original'] = (df_capology['Adj. GrossBase Salary(2021, IN GBP)']
                                                                            .combine_first(df_capology['Adj. GrossBase Salary(2021, IN EUR)'])
#                                                                             .combine_first(df_capology['Adj. GrossBase Salary(2021, IN USD)'])
                                                                            .replace('None', np.nan)
                                                                            .astype(float)
                                                                       )

df_capology['Adj. Gross Base Salary for Current Season GBP'] = df_capology['Adj. Gross Base Salary for Current Season Original'] * df_capology['Exchange Rate']

df_capology['Adj. Gross Base Salary for Current Season GBP'] = (df_capology['Adj. Gross Base Salary for Current Season GBP']
                                                                        .fillna(-1)
                                                                        .astype(int)
                                                                        .astype(str)
                                                                        .replace('-1', np.nan)
                                                                   )


## Coalesce the two status columns

###
df_capology['Status'] = (df_capology[df_capology.columns[13]]
#                                 .combine_first(df_capology['RosterStatus'])
#                                 .combine_first(df_capology['EstimatedGross Total(IN USD)'])
                                .replace('None', np.nan)
                                .astype(str)
                           )

# %%
df_capology = df_capology[~df_capology[df_capology.columns[11]].isin(['No data available in table'])]

# %%
df_capology[df_capology.columns[11]].unique()
# Out:
# array(['DM', 'RB', 'LB', 'CF', 'CB', 'LW', 'GK', 'AM', 'CM', 'RW', nan],
#       dtype=object)

# %%
## Map Positions

### 
dict_positions_grouped = {'K': 'Goalkeeper',
                          'D': 'Defender',
                          'M': 'Midfielder',
                          'F': 'Forward',
                          'GK': 'Goalkeeper',
                          'LB': 'Defender',
                          'RB': 'Defender',
                          'CB': 'Defender',
                          'DM': 'Midfielder',
                          'LM': 'Midfielder',
                          'CM': 'Midfielder',
                          'RM': 'Midfielder',
                          'AM': 'Midfielder',
                          'LW': 'Forward',
                          'RW': 'Forward',
                          'SS': 'Forward',
                          'CF': 'Forward'
                         }

### Map grouped positions to DataFrame
df_capology['Pos.'] = df_capology[df_capology.columns[11]].map(dict_positions_grouped)

# %%
## Separate Goalkeeper and Outfielders
df_capology['Outfielder Goalkeeper'] = np.where(df_capology['Pos.'].isnull(), np.nan, (np.where(df_capology['Pos.'] == 'Goalkeeper', 'Goalkeeper', 'Outfielder')))


## Define columns
cols = ['Player',
        'Season',
        'League',
        'Team',
        'Pos.',
        'Outfielder Goalkeeper',
        'Age',
        'Country',   
        'Weekly Gross Base Salary GBP',
        'Annual Gross Base Salary GBP',
        'Adj. Gross Base Salary for Current Season GBP',
        'Estimated Gross Total GBP',
        'Status',
        'Expiration',
        'Length'
       ]

## Select columns of interest
df_capology_select = df_capology[cols]

## Sort by 'mins_total' decending
df_capology_select = df_capology_select.sort_values(['League', 'Season', 'Team', 'Player'], ascending=[True, True, True, True])

## Drop index
df_capology_select = df_capology_select.reset_index(drop=True)

## Rename columns
df_capology_select = (df_capology_select
                             .rename(columns={'Player': 'player',
                                              'Season': 'season',
                                              'League': 'league',
                                              'Team': 'team',
                                              'Pos.': 'position',
                                              'Outfielder Goalkeeper': 'outfielder_goalkeeper',
                                              'Age': 'age',
                                              'Country': 'country',
                                              'Weekly Gross Base Salary GBP': 'weekly_gross_base_salary_gbp',
                                              'Annual Gross Base Salary GBP': 'annual_gross_base_salary_gbp',
                                              'Adj. Gross Base Salary for Current Season GBP': 'adj_current_gross_base_salary_gbp',
                                              'Estimated Gross Total GBP': 'estimated_gross_total_gbp',
                                              'Status': 'current_contract_status',
                                              'Expiration': 'current_contract_expiration',
                                              'Length': 'current_contract_length',
                                             }
                                    )
                        )

## 
df_capology_select.head(10)
# Out:
#              player     season      league      team    position  \
# 0     Aaron Zehnter  2022-2023  Bundesliga  Augsburg    Defender
# 1        André Hahn  2022-2023  Bundesliga  Augsburg     Forward
# 2       Arne Engels  2022-2023  Bundesliga  Augsburg  Midfielder
# 3        Arne Maier  2022-2023  Bundesliga  Augsburg  Midfielder
# 4   Benjamin Leneis  2022-2023  Bundesliga  Augsburg  Goalkeeper
# 5  Daniel Caligiuri  2022-2023  Bundesliga  Augsburg     Forward
# 6      Daniel Klein  2022-2023  Bundesliga  Augsburg  Goalkeeper
# 7      David Colina  2022-2023  Bundesliga  Augsburg    Defender
# 8        Dion Beljo  2022-2023  Bundesliga  Augsburg     Forward
# 9   Elvis Rexhbecaj  2022-2023  Bundesliga  Augsburg  Midfielder
#
#   outfielder_goalkeeper   age  country weekly_gross_base_salary_gbp  \
# 0            Outfielder  18.0  Germany                          845
# 1            Outfielder  32.0  Germany                        27053
# 2            Outfielder  19.0  Belgium                            0
# 3            Outfielder  24.0  Germany                        10821
# 4            Goalkeeper  23.0  Germany                         1521
# 5            Outfielder  35.0    Italy                        35508
# 6            Goalkeeper  21.0  Germany                          338
# 7            Outfielder  22.0  Croatia                            0
# 8            Outfielder  20.0  Croatia                            0
# 9            Outfielder  25.0  Germany                        23333
#
#   annual_gross_base_salary_gbp adj_current_gross_base_salary_gbp  \
# 0                        43962                               NaN
# 1                      1406800                               NaN
# 2                            0                               NaN
# 3                       562720                               NaN
# 4                        79132                               NaN
# 5                      1846425                               NaN
# 6                        17585                               NaN
# 7                            0                               NaN
# 8                            0                               NaN
# 9                      1213365                               NaN
#
#   estimated_gross_total_gbp current_contract_status  \
# 0                       NaN                 Reserve
# 1                       NaN                 Reserve
# 2                       NaN                 Starter
# 3                       NaN                 Starter
# 4                       NaN                 Reserve
# 5                       NaN                 Reserve
# 6                       NaN                 Reserve
# 7                       NaN                 Reserve
# 8                       NaN                 Starter
# 9                       NaN                 Starter
#
#   current_contract_expiration current_contract_length
# 0                Jun 30, 2024                     2.0
# 1                Jun 30, 2023                     1.0
# 2                Jun 30, 2027                     5.0
# 3                Jun 30, 2025                     3.0
# 4                Jun 30, 2023                     1.0
# 5                Jun 30, 2023                     1.0
# 6                Jun 30, 2025                     3.0
# 7                Jun 30, 2027                     5.0
# 8                Jun 30, 2027                     5.0
# 9                Jun 30, 2026                     4.0

# %%
# Still to engineer
# - 'current_contract_status', 'current_contract_expiration', and 'current_contract_length' are blank unless it's a 2021 
#   row. The 2021 data can be joined back onto the previous years. May however need to scrape more of the data to
#   get contract information of players no longer in same leage (i.e. relegation, move abroad)

# %%
df_capology.loc[df_capology['Player'] == 'Neymar']
# Out:
#       Unnamed: 0  Player Gross P/W(EUR) Gross P/Y(EUR) Gross P/Y(EUR).1  \
# 1534         394  Neymar    € 1,083,846   € 56,360,000              NaN
#
#            Signed  \
# 1534  May 8, 2021
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027  \
# 1534                                       Jun 30, 2025
#
#      Years Remaining 12345 Gross Remaining(EUR) Release Clause(EUR) Pos. DFKM  \
# 1534                   3.0        € 169,080,000                 NaN         F
#
#      Pos. AMCBCFCMDMGKLBLWRBRW   Age Status ReserveStarter Country  Active  \
# 1534                        LW  30.0               Starter  Brazil     NaN
#
#       Loan Team   League     Season Pos. AMCBCFCMDMGKLBLWRBSS  \
# 1534   NaN  Psg  Ligue 1  2022-2023                       NaN
#
#      Pos. CBCFCMDMGKLBLWRB  \
# 1534                   NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2027  \
# 1534                                                NaN
#
#      Years Remaining 1235 Pos. AMCBCFCMDMGKLBLMRBRW  \
# 1534                                            NaN
#
#      Pos. AMCBCFCMDMGKLBLMRBRMSS Pos. AMCBCFCMDMGKLBLMLWRBRMRW  \
# 1534                         NaN                           NaN
#
#      Pos. CBCFCMDMGKLBLMLWRBRW Pos. CBCFCMDMGKLBLWRBRW  \
# 1534                       NaN                     NaN
#
#      Pos. AMCBCFCMDMGKLBRBRWSS Pos. AMCBCFCMDMGKLBLMLWRBRWSS  \
# 1534                       NaN                           NaN
#
#      Pos. CBCFCMDMGKLBRBRM  \
# 1534                   NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026  \
# 1534                                                NaN
#
#      Years Remaining 1234 Pos. AMCBCFCMDMGKLBLMLWRBRW Pos. AMCBCFCMDMGKLWRBRW  \
# 1534                                              NaN                     NaN
#
#      Pos. AMCBCFCMDMGKLBRBRW Gross P/W(GBP) Gross P/Y(GBP) Gross P/Y(GBP).1  \
# 1534                     NaN            NaN            NaN              NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028  \
# 1534                                                NaN
#
#      Years Remaining 123456 Gross Remaining(GBP) Release Clause(GBP)  \
# 1534                                         NaN                 NaN
#
#      Pos. AMCBCFDMGKLBLWRBRMRW  \
# 1534                       NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028May 31, 2023  \
# 1534                                                NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027May 31, 2023  \
# 1534                                                NaN
#
#      Pos. AMCBCFCMGKLBLMLWRBSS  \
# 1534                       NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028Jun 30, 2029Jun 30, 2030Jun 30, 2031  \
# 1534                                                NaN
#
#      Years Remaining 123456789 Pos. AMCBCFCMDMGKLBLWRBRWSS  \
# 1534                                                   NaN
#
#      Pos. AMCBCFCMDMGKLBLMLWRBRM Pos. AMCBCFCMDMGKLBLWRBRMRW  \
# 1534                         NaN                         NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2029May 31, 2023  \
# 1534                                                NaN
#
#      Years Remaining 123457  \
# 1534
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025  \
# 1534                                                NaN
#
#      Years Remaining 123 Pos. CBCFCMGKLBRBRMRW Pos. AMCBCFCMDMGKLBLWRB  \
# 1534                                       NaN                     NaN
#
#      Pos. AMCBCFCMDMGKLBRBRM Pos. CBCFCMDMGKLBLWRBRMRW  \
# 1534                     NaN                       NaN
#
#      Pos. AMCBCFDMGKLBLWRBRW Pos. AMCBCFCMDMGKLBLMRB  \
# 1534                     NaN                     NaN
#
#      Contract Expiration Dec 31, 2023Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027  \
# 1534                                                NaN
#
#      Pos. AMCBCFCMDMGKLBLWRBRM Pos. CBCFCMDMGKLBLWRBRWSS  \
# 1534                       NaN                       NaN
#
#      Pos. AMCBCFCMGKLBLWRBSS Pos. AMCBCFCMDMGKLBRBSS Pos. CBCFCMDMGKLBRBRW  \
# 1534                     NaN                     NaN                   NaN
#
#      Contract Expiration Jun 23, 2023Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027  \
# 1534                                                NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2031  \
# 1534                                                NaN
#
#      Years Remaining 123459 Pos. AMCBCFCMGKLBLWRBRW  \
# 1534                                            NaN
#
#      Contract Expiration Jun 30, 2023Jun 30, 2024Jun 30, 2025Jun 30, 2026Jun 30, 2027Jun 30, 2028Jun 30, 2029  \
# 1534                                                NaN
#
#      Years Remaining 1234567  Weekly GrossBase Salary(IN EUR)  \
# 1534                                                1083846.0
#
#       Annual GrossBase Salary(IN EUR)  EstimatedGross Total(IN EUR)  \
# 1534                       56360000.0                   169080000.0
#
#       Adj. GrossBase Salary(2021, IN EUR)  Weekly GrossBase Salary(IN GBP)  \
# 1534                                  NaN                              NaN
#
#       Annual GrossBase Salary(IN GBP)  EstimatedGross Total(IN GBP)  \
# 1534                              NaN                           NaN
#
#       Adj. GrossBase Salary(2021, IN GBP) Currency  Exchange Rate  \
# 1534                                  NaN      EUR        0.87925
#
#         Expiration Length     Pos.  Estimated Gross Total Original  \
# 1534  Jun 30, 2025    3.0  Forward                             NaN
#
#      Estimated Gross Total GBP  Weekly Gross Base Salary Original  \
# 1534                       NaN                          1083846.0
#
#      Weekly Gross Base Salary GBP  Annual Gross Base Salary Original  \
# 1534                       952971                         56360000.0
#
#      Annual Gross Base Salary GBP  \
# 1534                     49554530
#
#       Adj. Gross Base Salary for Current Season Original  \
# 1534                                                NaN
#
#      Adj. Gross Base Salary for Current Season GBP   Status  \
# 1534                                           NaN  Starter
#
#      Outfielder Goalkeeper
# 1534            Outfielder

# %%
df_capology_select.loc[df_capology_select['player'] == 'Neymar']
# Out:
#       player     season   league team position outfielder_goalkeeper   age  \
# 1416  Neymar  2022-2023  Ligue 1  Psg  Forward            Outfielder  30.0
#
#      country weekly_gross_base_salary_gbp annual_gross_base_salary_gbp  \
# 1416  Brazil                       952971                     49554530
#
#      adj_current_gross_base_salary_gbp estimated_gross_total_gbp  \
# 1416                               NaN                       NaN
#
#      current_contract_status current_contract_expiration  \
# 1416                 Starter                Jun 30, 2025
#
#      current_contract_length
# 1416                     3.0

# %% [markdown]
# ### <a id='#section4.3'>4.3. Create Wide Dataset
# 1 row per player

# %%
# CODE HERE

# %% [markdown]
# ### <a id='#section4.4'>4.4. Filter Players in 'Big 5' European Leagues
# Create a separate DataFrame

# %%
df_capology_select['league'].unique()
# Out:
# array(['Bundesliga', 'La Liga', 'Ligue 1', 'Premier League', 'Serie A'],
#       dtype=object)

# %%
# Filter plays in the Big 5 European Leagues

## Define list of countries
lst_big5_countries = ['Bundesliga', 'Ligue 1', 'Premier League', 'Serie A', 'La Liga']

## Filter list of Big 5 European League countries from DataFrame
df_capology_big5_mls_select = df_capology_select[df_capology_select['league'].isin(lst_big5_countries)]

# %%
df_capology_big5_mls_select.shape
# Out:
# (2655, 15)

# %% [markdown]
# ---
#
# <a id='section5'></a>
#
# ## <a id='#section5'>5. Export Datasets</a>

# %%
# Export DataFrames

## All teams
df_capology_select.to_csv(data_dir_capology + f'/engineered/archive/capology_all_2223_last_updated_{today}.csv', index=None, header=True)
df_capology_select.to_csv(data_dir_capology + '/engineered/capology_all_latest.csv', index=None, header=True)

## Teams from the 'Big 5' European leagues and MLS
df_capology_big5_mls_select.to_csv(data_dir_capology + f'/engineered/archive/capology_big5_2223_last_updated_{today}.csv', index=None, header=True)
df_capology_big5_mls_select.to_csv(data_dir_capology + '/engineered/capology_big5_latest.csv', index=None, header=True)

# %% [markdown]
# ---
#
# <a id='section6'></a>
#
# ## <a id='#section6'>6. Summary</a>
# This notebook scrapes player statstics data from [Capology](https://www.capology.com/), using [pandas](http://pandas.pydata.org/) for data manipulation through DataFrames.

# %% [markdown]
# ___
#
# <a id='section7'></a>
#
# ## <a id='#section7'>7. Next Steps</a>
# This engineered data is now ready to be analysed and joined to further engineered and joined to disparate datasets such as data from FBref and TransferMarkt.

# %% [markdown]
# ___
#
# <a id='section8'></a>
#
# ## <a id='#section8'>8. References</a>
#
# #### Data and Web Scraping
# *
# *
# *

# %% [markdown]
# ---
#
# ***Visit my website [eddwebster.com](https://www.eddwebster.com) or my [GitHub Repository](https://github.com/eddwebster) for more projects. If you'd like to get in contact, my Twitter handle is [@eddwebster](http://www.twitter.com/eddwebster) and my email is: edd.j.webster@gmail.com.***

# %% [markdown]
# [Back to the top](#top)
